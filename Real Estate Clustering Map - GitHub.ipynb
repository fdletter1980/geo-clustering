# %% [markdown]
# # Install and import key Libraries

# %%
# pip install geopandas
# pip install geopy
# pip install folium

# %%
import pandas as pd
#import geopandas as gpd
import geopy
#from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster
#!/usr/bin/env python3
import csv
import time
from csv import Dialect

from geopy.exc import (
    GeocoderQueryError,
    GeocoderQuotaExceeded,
    ConfigurationError,
    GeocoderParseError,
    GeocoderTimedOut
)

# %% [markdown]
# # Geocode input real-estate listings through Google API

# %%
path = "ADD DIRECTORY PATH"

# %%
# used to set a google geocoding query by merging this value into one string with comma separated
#ADDRESS_COLUMNS_NAME = ["name", "addressline1", "town"]
ADDRESS_COLUMNS_NAME = ["street", "city", "state", "zip_code"]
# used to define component restrictions for google geocoding
COMPONENT_RESTRICTIONS_COLUMNS_NAME = {}

# appended columns name to processed data csv
NEW_COLUMNS_NAME = ["Lat", "Long", "Error", "formatted_address", "location_type"]

# delimiter for input csv file
DELIMITER = ","

# Automatically retry X times when GeocoderErrors occur (sometimes the API Service return intermittent failures).
RETRY_COUNTER_CONST = 5

# name for output csv file
INPUT_CSV_FILE = path + "/NewYork.csv"

# name for output csv file
OUTPUT_CSV_FILE = path + "/NewYork-geocoded.csv"

# google keys - see https://dev.to/gaelsimon/bulk-geocode-addresses-using-google-maps-and-geopy-5bmg for more details
GOOGLE_API_KEY = "ADD API KEY"  # it's the new mandatory parameter

# dialect to manage different format of CSV
class CustomDialect(Dialect):
    delimiter = DELIMITER
    quotechar = '"'
    doublequote = True
    skipinitialspace = True
    lineterminator = '\n'
    quoting = csv.QUOTE_ALL


csv.register_dialect('ga', CustomDialect)

# %%
def process_addresses_from_csv():
    geo_locator = GoogleV3(api_key=GOOGLE_API_KEY)

    with open(INPUT_CSV_FILE, 'r') as csvinput:
        with open(OUTPUT_CSV_FILE, 'w') as csvoutput:

            # new csv based on same dialect as input csv
            writer = csv.writer(csvoutput, dialect="ga")

            # create a proper header with stripped fieldnames for new CSV
            header = [h.strip('"').strip() for h in next(csvinput).split(DELIMITER)]
            # read Input CSV as Dict of Dict
            reader = csv.DictReader(csvinput, dialect="ga", fieldnames=header)

            # append new columns, to receive geocoded information, to the header of the new CSV
            header = list(reader.fieldnames)
            for column_name in NEW_COLUMNS_NAME:
                header.append(column_name)
            writer.writerow([s.strip() for s in header])

            # iterate through each row of input CSV
            for record in reader:
                # build a line address based on the merge of multiple field values to pass to Google Geocoder
                line_address = ','.join(
                    str(val) for val in (record[column_name] for column_name in ADDRESS_COLUMNS_NAME))
                #line_address = ADDRESS_COLUMNS_NAME
                
                # if you want to use componentRestrictions feature,
                # build a matching dict {'googleComponentRestrictionField' : 'yourCSVFieldValue'}
                # to pass to Google Geocoder
                component_restrictions = {}
                if COMPONENT_RESTRICTIONS_COLUMNS_NAME:
                    for key, value in COMPONENT_RESTRICTIONS_COLUMNS_NAME.items():
                        component_restrictions[key] = record[value]

                # geocode the built line_address and passing optional componentRestrictions
                location = geocode_address(geo_locator, line_address, component_restrictions)

                # build a new temp_row for each csv entry to append to process_data Array
                # first, append existing fieldnames value to this temp_row
                temp_row = [record[column_name] for column_name in reader.fieldnames]
                # then, append geocoded field value to this temp_row
                for column_name in NEW_COLUMNS_NAME:
                    try:
                        temp_row.append(location[column_name])
                    except BaseException as error:
                        print(error)
                        temp_row.append('')

                # Finally append your row with geocoded values with csvwriter.writerow(temp_row)
                try:
                    writer.writerow(temp_row)
                except BaseException as error:
                    print(error)
                    print(temp_row)

# %%
def geocode_address(geo_locator, line_address, component_restrictions=None, retry_counter=1):
    time.sleep(1)
    try:
        # the geopy GoogleV3 geocoding call
        location = geo_locator.geocode(line_address, components=component_restrictions)

        if location is not None:
            # build a dict to append to output CSV
            location_result = {"Lat": location.latitude, "Long": location.longitude, "Error": "",
                               "formatted_address": location.raw['formatted_address'],
                               "location_type": location.raw['geometry']['location_type']}
        else:
            location_result = {"Lat": 0, "Long": 0,
                               "Error": "None location found, please verify your address line",
                               "formatted_address": "",
                               "location_type": ""}

    # To catch generic geocoder errors.
    except (ValueError, GeocoderQuotaExceeded, ConfigurationError, GeocoderParseError) as error:
        if hasattr(error, 'message'):
            error_message = error.message
        else:
            error_message = error
        location_result = {"Lat": 0, "Long": 0, "Error": error_message, "formatted_address": "", "location_type": ""}

    # To retry because intermittent failures and timeout sometimes occurs
    except (GeocoderTimedOut, GeocoderQueryError) as geocodingerror:
        if retry_counter < RETRY_COUNTER_CONST:
            return geocode_address(geo_locator, line_address, component_restrictions, retry_counter + 1)
        else:
            if hasattr(geocodingerror, 'message'):
                error_message = geocodingerror.message
            else:
                error_message = geocodingerror
            location_result = {"Lat": 0, "Long": 0, "Error": error_message, "formatted_address": "",
                               "location_type": ""}
    # To retry because intermittent failures and timeout sometimes occurs
    except BaseException as error:
        if retry_counter < RETRY_COUNTER_CONST:
            time.sleep(5)
            return geocode_address(geo_locator, line_address, component_restrictions, retry_counter + 1)
        else:
            location_result = {"Lat": 0, "Long": 0, "Error": error, "formatted_address": "",
                               "location_type": ""}

    print("address line     : {0}".format(line_address))
    print("geocoded address : {0}".format(location_result["formatted_address"]))
    print("location type    : {0}".format(location_result["location_type"]))
    print("Lat/Long         : [{0},{1}]".format(location_result["Lat"], location_result["Long"]))
    print("-------------------")

    return location_result


if __name__ == '__main__':
    process_addresses_from_csv()
# Out:
# address line     : 350 E 81st St Apt 3,New York City,New York,10028
# geocoded address : 350 E 81st St #3, New York, NY 10028, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7737326,-73.9524453]
# -------------------
# address line     : 25 N Moore St Unit 16ABC,New York City,New York,10013
# geocoded address : 25 N Moore St, New York, NY 10013, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7199482,-74.00710579999999]
# -------------------
# address line     : 5900 Arlington Ave Apt 2M,New York City,New York,10471
# geocoded address : 5900 Arlington Ave #2m, The Bronx, NY 10471, USA
# location type    : ROOFTOP
# Lat/Long         : [40.9090953,-73.90564359999999]
# -------------------
# address line     : 50 Sutton Pl S Apt 8K,New York City,New York,10022
# geocoded address : 50 Sutton Pl S #8k, New York, NY 10022, USA
# location type    : ROOFTOP
# Lat/Long         : [40.75595029999999,-73.9621113]
# -------------------
# address line     : 215 E 96th St Unit 37F,New York City,New York,10128
# geocoded address : One Carnegie Hill, 215 E 96th St #37f, New York, NY 10128, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7851883,-73.947968]
# -------------------
# address line     : ,New York City,New York,10452
# geocoded address : The Bronx, NY 10452, USA
# location type    : APPROXIMATE
# Lat/Long         : [40.8376318,-73.92128579999999]
# -------------------
# address line     : 105 W 70th St Apt 1R,New York City,New York,10023
# geocoded address : 105 W 70th St #1r, New York, NY 10023, USA
# location type    : ROOFTOP
# Lat/Long         : [40.776418,-73.979925]
# -------------------
# address line     : 270 W 17th St Apt 12A,New York City,New York,10011
# geocoded address : 270 W 17th St #12a, New York, NY 10011, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7412309,-74.0010072]
# -------------------
# address line     : 122 Congress St,New York City,New York,11201
# geocoded address : 122 Congress St, Brooklyn, NY 11201, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6889347,-73.99820489999999]
# -------------------
# address line     : 430 E 56th St Apt 1C,New York City,New York,10022
# geocoded address : 430 E 56th St #1c, New York, NY 10022, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7569833,-73.96245569999999]
# -------------------
# address line     : 40 Bond St Apt 6A,New York City,New York,10012
# geocoded address : 40 Bond St #6a, New York, NY 10012, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7265073,-73.9933102]
# -------------------
# address line     : 303 W 29th St Apt A,New York City,New York,10001
# geocoded address : 303 W 29th St A, New York, NY 10001, USA
# location type    : ROOFTOP
# Lat/Long         : [40.749446,-73.9960849]
# -------------------
# address line     : 150 E 56th St Unit 1A /B,New York City,New York,10022
# geocoded address : 1 E 56th St, New York, NY 10022, USA
# location type    : RANGE_INTERPOLATED
# Lat/Long         : [40.7622773,-73.97442989999999]
# -------------------
# address line     : 116 Willoughby Ave,New York City,New York,11205
# geocoded address : 116 Willoughby Ave, Brooklyn, NY 11205, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6914524,-73.9678265]
# -------------------
# address line     : 885 W End Ave Apt 12D,New York City,New York,10025
# geocoded address : 885 West End Ave #12d, New York, NY 10025, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8000117,-73.9701698]
# -------------------
# address line     : 300 E 40th St Apt 21S,New York City,New York,10016
# geocoded address : 300 E 40th St #21s, New York, NY 10016, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7480655,-73.97286199999999]
# -------------------
# address line     : 8 W 71st St,New York City,New York,10023
# geocoded address : 8 W 71st St, New York, NY 10023, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7756416,-73.97720629999999]
# -------------------
# address line     : 121 E 23rd St Apt 20C,New York City,New York,10010
# geocoded address : 121 E 23rd St #20c, New York, NY 10010, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7400441,-73.98537019999999]
# -------------------
# address line     : 101 E 2nd St Apt 4C,New York City,New York,10009
# geocoded address : 101 E 2nd St #4c, New York, NY 10009, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7235881,-73.98764190000001]
# -------------------
# address line     : 400 E 77th St Apt 7E,New York City,New York,10075
# geocoded address : 400 E 77th St #7e, New York, NY 10075, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7707233,-73.95335039999999]
# -------------------
# address line     : 345 Webster Ave Apt 5I,New York City,New York,11230
# geocoded address : 345 Webster Ave #5i, Brooklyn, NY 11230, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6339914,-73.9689071]
# -------------------
# address line     : 191 Willoughby St Apt 7F,New York City,New York,11201
# geocoded address : 191 Willoughby St #7f, Brooklyn, NY 11201, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6925254,-73.9803939]
# -------------------
# address line     : 105 Bennett Ave Unit 44B,New York City,New York,10033
# geocoded address : 105 Bennett Ave #44b, New York, NY 10033, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8539526,-73.9345678]
# -------------------
# address line     : 47-49 King St Unit 8,New York City,New York,10014
# geocoded address : 47 King St #49, New York, NY 10014, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7280229,-74.0048053]
# -------------------
# address line     : 345 E 81st St Apt 2N,New York City,New York,10028
# geocoded address : 345 E 81st St #2n, New York, NY 10028, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7740666,-73.9522989]
# -------------------
# address line     : 808 Broadway Apt 3K,New York City,New York,10003
# geocoded address : 808 Broadway #3k, New York, NY 10003, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7324361,-73.9909751]
# -------------------
# address line     : 63 E 9th St Apt 12H,New York City,New York,10003
# geocoded address : 63 E 9th St #12h, New York, NY 10003, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7314129,-73.9921518]
# -------------------
# address line     : 301 E 79th St Apt 31C,New York City,New York,10075
# geocoded address : 301 E 79th St #31c, New York, NY 10075, USA
# location type    : ROOFTOP
# Lat/Long         : [40.77330449999999,-73.9543976]
# -------------------
# address line     : 15 Renwick St Apt 601,New York City,New York,10013
# geocoded address : 15 Renwick St APT 601, New York, NY 10013, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7249484,-74.00870789999999]
# -------------------
# address line     : 17 W 67th St Apt 3F,New York City,New York,10023
# geocoded address : 17 W 67th St #3f, New York, NY 10023, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7737734,-73.97946759999999]
# -------------------
# address line     : 400 5th Ave Unit 39FGH,New York City,New York,10018
# geocoded address : 400 5th Ave, New York, NY 10018, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7500752,-73.9837835]
# -------------------
# address line     : 251 W 91st St Unit 10B,New York City,New York,10024
# geocoded address : 251 W 91st St #10b, New York, NY 10024, USA
# location type    : ROOFTOP
# Lat/Long         : [40.79173970000001,-73.9744247]
# -------------------
# address line     : 111 Montgomery St Apt 5B,New York City,New York,11225
# geocoded address : 111 Montgomery St #5b, Brooklyn, NY 11225, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6666793,-73.9609528]
# -------------------
# address line     : 137 4th Ave Unit 3,New York City,New York,11217
# geocoded address : 137 4th Ave #3, Brooklyn, NY 11217, USA
# location type    : ROOFTOP
# Lat/Long         : [40.679581,-73.9812951]
# -------------------
# address line     : 98 Front St Apt 6R,New York City,New York,11201
# geocoded address : 98 Front St #6r, Brooklyn, NY 11201, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7024285,-73.9888337]
# -------------------
# address line     : 169 Huron St Ph A,New York City,New York,11222
# geocoded address : 169 Huron St, Brooklyn, NY 11222, USA
# location type    : RANGE_INTERPOLATED
# Lat/Long         : [40.7332472,-73.9543487]
# -------------------
# address line     : 294 Smith St Unit 1,New York City,New York,11231
# geocoded address : 294 Smith St #1, Brooklyn, NY 11231, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6820161,-73.993894]
# -------------------
# address line     : 260 W Broadway Units 3 & 4F,New York City,New York,10013
# geocoded address : 260 W Broadway, New York, NY 10013, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7205254,-74.0057286]
# -------------------
# address line     : 120 E 83rd St Apt 2B,New York City,New York,10028
# geocoded address : 120 E 83rd St #2b, New York, NY 10028, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7776132,-73.95769159999999]
# -------------------
# address line     : 139 E 66th St Apt 5S,New York City,New York,10065
# geocoded address : 139 E 66th St #5s, New York, NY 10065, USA
# location type    : ROOFTOP
# Lat/Long         : [40.766423,-73.9640148]
# -------------------
# address line     : 119 W 22nd St Apt 2,New York City,New York,10011
# geocoded address : 119 W 22nd St #2, New York, NY 10011, USA
# location type    : ROOFTOP
# Lat/Long         : [40.74275979999999,-73.99405279999999]
# -------------------
# address line     : 425 W 53rd St Apt 418,New York City,New York,10019
# geocoded address : 425 W 53rd St #418, New York, NY 10019, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7659512,-73.98847479999999]
# -------------------
# address line     : 10 Bleecker St Unit TH1,New York City,New York,10012
# geocoded address : 10 Bleecker St, New York, NY 10012, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7252187,-73.9929764]
# -------------------
# address line     : 39 W 23rd St Apt 7A,New York City,New York,10010
# geocoded address : 39 W 23rd St #7a, New York, NY 10010, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7425001,-73.9908777]
# -------------------
# address line     : ,New York City,New York,10024
# geocoded address : New York, NY 10024, USA
# location type    : APPROXIMATE
# Lat/Long         : [40.7859464,-73.97418739999999]
# -------------------
# address line     : 408 W 57th St Apt 9G,New York City,New York,10019
# geocoded address : The Geneva, 408 W 57th St #9g, New York, NY 10019, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7680768,-73.98663]
# -------------------
# address line     : 158-18 Riverside Dr W Unit 6J,New York City,New York,10032
# geocoded address : 158-18 Riverside Dr W #6j, New York, NY 10032, USA
# location type    : ROOFTOP
# Lat/Long         : [40.837124,-73.9478519]
# -------------------
# address line     : 33-45 92nd St Unit 3J,New York City,New York,11369
# geocoded address : 33-45 92nd St #3j, Queens, NY 11372, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7550328,-73.875632]
# -------------------
# address line     : 35-20 31st St,New York City,New York,11106
# geocoded address : 35-20 31st St, Queens, NY 11106, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7576927,-73.92920819999999]
# -------------------
# address line     : 79 Barrow St Apt 6C,New York City,New York,10014
# geocoded address : 79 Barrow St #6c, New York, NY 10014, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7313911,-74.00590079999999]
# -------------------
# address line     : 50 Park Ave # B,New York City,New York,10016
# geocoded address : 50 Park Ave b, New York, NY 10016, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7493387,-73.9803235]
# -------------------
# address line     : 26-14 28th St Unit 4B,New York City,New York,11102
# geocoded address : 26-14 28th St #4b, Queens, NY 11102, USA
# location type    : ROOFTOP
# Lat/Long         : [40.770517,-73.92143999999999]
# -------------------
# address line     : 185 Grand St Apt 4D,New York City,New York,10013
# geocoded address : 185 Grand St #4d, Brooklyn, NY 11211, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7144322,-73.96075669999999]
# -------------------
# address line     : 5 Hampton Pl,New York City,New York,11213
# geocoded address : 5 Hampton Pl, Brooklyn, NY 11213, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6726258,-73.9405975]
# -------------------
# address line     : 25 Tudor City Pl Apt 1111,New York City,New York,10017
# geocoded address : 25 Tudor City Pl Apt 1111, New York, NY 10017, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7484484,-73.97069359999999]
# -------------------
# address line     : 317 E 18th St Apt 6A,New York City,New York,10003
# geocoded address : 317 E 18th St #6a, New York, NY 10003, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7346548,-73.982112]
# -------------------
# address line     : 299 Henry Unit D1-4th St # #flr,New York City,New York,11201
# geocoded address : 4th St, Brooklyn, NY, USA
# location type    : GEOMETRIC_CENTER
# Lat/Long         : [40.6728165,-73.9850787]
# -------------------
# address line     : 854 W 181st St Apt 3H,New York City,New York,10033
# geocoded address : 854 W 181st St #3h, New York, NY 10033, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8511379,-73.9399545]
# -------------------
# address line     : 170 E 87th St Unit E16,New York City,New York,10128
# geocoded address : 170 E 87th St e16, New York, NY 10128, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7795712,-73.9540221]
# -------------------
# address line     : 5-19 Borden Ave Unit 3F,New York City,New York,11101
# geocoded address : 5-19 Borden Ave #3f, Long Island City, NY 11101, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7417859,-73.9558663]
# -------------------
# address line     : 32 W 18th St Apt 2A,New York City,New York,10011
# geocoded address : 32 W 18th St #2a, New York, NY 10011, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7390659,-73.9937922]
# -------------------
# address line     : 1623-1641 3rd Ave Unit 35H,New York City,New York,10128
# geocoded address : 1623 3rd Ave #35h, New York, NY 10128, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7819416,-73.95063139999999]
# -------------------
# address line     : 64 Macdougal St Apt 8,New York City,New York,10012
# geocoded address : 64 MacDougal St Apt 8, New York, NY 10012, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7278259,-74.0021323]
# -------------------
# address line     : 345 E 77th St Apt 2D,New York City,New York,10075
# geocoded address : 345 E 77th St #2d, New York, NY 10075, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7714227,-73.9542156]
# -------------------
# address line     : 40 Leroy St,New York City,New York,10014
# geocoded address : 40 Leroy St, New York, NY 10014, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7303011,-74.00433989999999]
# -------------------
# address line     : 77 Park Ter E Apt D16,New York City,New York,10034
# geocoded address : 77 Park Terrace E d16, New York, NY 10034, USA
# location type    : ROOFTOP
# Lat/Long         : [40.871051,-73.916134]
# -------------------
# address line     : 135 Division St Apt 7B,New York City,New York,10002
# geocoded address : 135 Division St #7b, New York, NY 10002, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7143903,-73.99115259999999]
# -------------------
# address line     : ,New York City,New York,11368
# geocoded address : Corona, NY 11368, USA
# location type    : APPROXIMATE
# Lat/Long         : [40.7506343,-73.8477874]
# -------------------
# address line     : 58 Downing St,New York City,New York,10014
# geocoded address : 58 Downing St, New York, NY 10014, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7289147,-74.0046383]
# -------------------
# address line     : 111 Montgomery St Apt 4D,New York City,New York,11225
# geocoded address : 111 Montgomery St #4d, Brooklyn, NY 11225, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6666793,-73.9609528]
# -------------------
# address line     : 66 Reade St Unit 3,New York City,New York,10007
# geocoded address : 66 Reade St #3, New York, NY 10007, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7151591,-74.00668499999999]
# -------------------
# address line     : 545 W End Ave Apt 16A,New York City,New York,10024
# geocoded address : 545 West End Ave #16a, New York, NY 10024, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7892103,-73.9780213]
# -------------------
# address line     : 306 Gold St Apt 10F,New York City,New York,11201
# geocoded address : 306 Gold St #10f, Brooklyn, NY 11201, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6950751,-73.9835386]
# -------------------
# address line     : 301 E 22nd St Unit 6UT,New York City,New York,10010
# geocoded address : 301 E 22nd St, New York, NY 10010, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7372683,-73.9809854]
# -------------------
# address line     : 301 E 22nd St Apt 11U,New York City,New York,10010
# geocoded address : 301 E 22nd St #11u, New York, NY 10010, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7372683,-73.9809854]
# -------------------
# address line     : 273 Albany Ave Apt 2A,New York City,New York,11213
# geocoded address : 273 Albany Ave #2a, Brooklyn, NY 11213, USA
# location type    : ROOFTOP
# Lat/Long         : [40.671435,-73.9389081]
# -------------------
# address line     : 11 Schermerhorn St Apt 1WF,New York City,New York,11201
# geocoded address : 11 Schermerhorn St Apt 1wf, Brooklyn, NY 11201, USA
# location type    : ROOFTOP
# Lat/Long         : [40.69155260000001,-73.9932472]
# -------------------
# address line     : 365 W 20th St Apt 14E,New York City,New York,10011
# geocoded address : 365 W 20th St #14e, New York, NY 10011, USA
# location type    : ROOFTOP
# Lat/Long         : [40.74458389999999,-74.0023215]
# -------------------
# address line     : 30 West St Apt 10B,New York City,New York,10004
# geocoded address : 30 West St #10b, New York, NY 10004, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7063162,-74.0169708]
# -------------------
# address line     : 245 E 54th St Apt 3S,New York City,New York,10022
# geocoded address : 245 E 54th St #3s, New York, NY 10022, USA
# location type    : ROOFTOP
# Lat/Long         : [40.75777370000001,-73.9667949]
# -------------------
# address line     : 65-15 38th Ave Unit 3J,New York City,New York,11377
# geocoded address : 65-15 38th Ave #3j, Queens, NY 11377, USA
# location type    : ROOFTOP
# Lat/Long         : [40.747278,-73.8978449]
# -------------------
# address line     : 212 E 32nd St,New York City,New York,10016
# geocoded address : 212 E 32nd St, New York, NY 10016, USA
# location type    : ROOFTOP
# Lat/Long         : [40.744024,-73.9784526]
# -------------------
# address line     : 669 Washington Ave,New York City,New York,11238
# geocoded address : 669 Washington Ave, Brooklyn, NY 11238, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6771471,-73.9634181]
# -------------------
# address line     : 425 W 50th St Apt 12H,New York City,New York,10019
# geocoded address : 425 W 50th St #12h, New York, NY 10019, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7641461,-73.9901764]
# -------------------
# address line     : 27 Bethune St,New York City,New York,10014
# geocoded address : 27 Bethune St, New York, NY 10014, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7368391,-74.00735829999999]
# -------------------
# address line     : 462 E 138th St,New York City,New York,10454
# geocoded address : 462 E 138th St, The Bronx, NY 10454, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8081041,-73.9210446]
# -------------------
# address line     : 65-15 38th Ave Unit 6W,New York City,New York,11377
# geocoded address : 65-15 38th Ave #6w, Queens, NY 11377, USA
# location type    : ROOFTOP
# Lat/Long         : [40.747278,-73.8978449]
# -------------------
# address line     : 211 E 18th St Unit 2RST,New York City,New York,10003
# geocoded address : 211 E 18th St, New York, NY 10003, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7354659,-73.9841568]
# -------------------
# address line     : 114 E 65th St,New York City,New York,10065
# geocoded address : 114 E 65th St, New York, NY 10065, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7662142,-73.9664942]
# -------------------
# address line     : 682 Hancock St Unit 2B,New York City,New York,11233
# geocoded address : 682 Hancock St #2b, Brooklyn, NY 11233, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6848556,-73.9281863]
# -------------------
# address line     : 682 Hancock St Unit 3B,New York City,New York,11233
# geocoded address : 682 Hancock St #3b, Brooklyn, NY 11233, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6848556,-73.9281863]
# -------------------
# address line     : 682 Hancock St Unit 2A,New York City,New York,11233
# geocoded address : 682 Hancock St #2a, Brooklyn, NY 11233, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6848556,-73.9281863]
# -------------------
# address line     : 682 Hancock St Unit 3A,New York City,New York,11233
# geocoded address : 682 Hancock St #3a, Brooklyn, NY 11233, USA
# location type    : ROOFTOP
# Lat/Long         : [40.6848556,-73.9281863]
# -------------------
# address line     : 479 Lexington Ave Unit 2A,New York City,New York,11221
# geocoded address : 479 Lexington Ave #2a, New York, NY 10017, USA
# location type    : RANGE_INTERPOLATED
# Lat/Long         : [40.7538262,-73.97364650000002]
# -------------------
# address line     : 145 Sullivan St Apt 4D,New York City,New York,10012
# geocoded address : 145 Sullivan St #4d, New York, NY 10012, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7270036,-74.0016423]
# -------------------
# address line     : 128 W 70th St Apt 9,New York City,New York,10023
# geocoded address : 128 W 70th St Apt 9, New York, NY 10023, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7761138,-73.9801195]
# -------------------
# address line     : 145 E 15th St Apt 15B,New York City,New York,10003
# geocoded address : 145 E 15th St #15b, New York, NY 10003, USA
# location type    : ROOFTOP
# Lat/Long         : [40.7343053,-73.98690549999999]
# -------------------
# address line     : 300 W 135th St Apt 5E,New York City,New York,10030
# geocoded address : 300 W 135th St #5e, New York, NY 10027, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8163293,-73.9473251]
# -------------------
# address line     : 33 Park Unit 15B,New York City,New York,10038
# geocoded address : 33 Alden Park #15b, The Bronx, NY 10465, USA
# location type    : ROOFTOP
# Lat/Long         : [40.8225202,-73.8071197]
# -------------------
# address line     : ,New York City,New York,10010
# geocoded address : New York, NY 10010, USA
# location type    : APPROXIMATE
# Lat/Long         : [40.7388319,-73.98153370000001]
# -------------------

# %%
geo_locator = GoogleV3(api_key=GOOGLE_API_KEY)
geo_locator.geocode("New York City, USA")
# Out:
# Location(New York, NY, USA, (40.7127753, -74.0059728, 0.0))

# %%
df = pd.read_csv(path + '/NewYork-geocoded.csv')
df.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale   3600000  3.0   3.0       NaN
# 1  for_sale  22000000  5.0   6.0       NaN
# 2  for_sale    210000  1.0   1.0       NaN
# 3  for_sale    775000  1.0   2.0       NaN
# 4  for_sale    749000  1.0   1.0       NaN
#
#                                         full_address  \
# 0      350 E 81st St Apt 3, New York City, NY, 10028
# 1  25 N Moore St Unit 16ABC, New York City, NY, 1...
# 2  5900 Arlington Ave Apt 2M, New York City, NY, ...
# 3    50 Sutton Pl S Apt 8K, New York City, NY, 10022
# 4   215 E 96th St Unit 37F, New York City, NY, 10128
#
#                       street           city     state  zip_code  house_size  \
# 0        350 E 81st St Apt 3  New York City  New York     10028      2338.0
# 1   25 N Moore St Unit 16ABC  New York City  New York     10013      7020.0
# 2  5900 Arlington Ave Apt 2M  New York City  New York     10471         NaN
# 3      50 Sutton Pl S Apt 8K  New York City  New York     10022         NaN
# 4     215 E 96th St Unit 37F  New York City  New York     10128         NaN
#
#    sold_date        Lat       Long  \
# 0        NaN  40.773733 -73.952445
# 1  10/6/2015  40.719948 -74.007106
# 2        NaN  40.909095 -73.905644
# 3        NaN  40.755950 -73.962111
# 4        NaN  40.785188 -73.947968
#
#                                    formatted_address location_type
# 0          350 E 81st St #3, New York, NY 10028, USA       ROOFTOP
# 1             25 N Moore St, New York, NY 10013, USA       ROOFTOP
# 2   5900 Arlington Ave #2m, The Bronx, NY 10471, USA       ROOFTOP
# 3        50 Sutton Pl S #8k, New York, NY 10022, USA       ROOFTOP
# 4  One Carnegie Hill, 215 E 96th St #37f, New Yor...       ROOFTOP

# %%
df.state.unique()
# Out:
# array(['New York'], dtype=object)

# %%
df.Lat.isnull().sum()
# Out:
# 0

# %%
#df = df[pd.notnull(df["Lat"])]

# %% [markdown]
# # Create clustering map

# %%
folium_map = folium.Map(location=[40.7127281,-74.0060152],
                        zoom_start=12,
                         tiles='cartodbpositron')
                        #tiles='CartoDB dark_matter')


FastMarkerCluster(data=list(zip(df['Lat'].values, df['Long'].values))).add_to(folium_map)

folium.LayerControl().add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4adb35988f383587c97de89256ed9bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4adb35988f383587c97de89256ed9bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4adb35988f383587c97de89256ed9bf = L.map(
#                 &quot;map_c4adb35988f383587c97de89256ed9bf&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dce51555eea9510bdb57d3317a1014f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4adb35988f383587c97de89256ed9bf);
#
#
#             var fast_marker_cluster_46c6e82dd7c48f30b76b55e351c5c6ee = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[40.7737326, -73.9524453], [40.7199482, -74.0071058], [40.9090953, -73.9056436], [40.7559503, -73.9621113], [40.7851883, -73.947968], [40.8376318, -73.9212858], [40.776418, -73.979925], [40.7412309, -74.0010072], [40.6889347, -73.9982049], [40.7569833, -73.9624557], [40.7265073, -73.9933102], [40.749446, -73.9960849], [40.7622773, -73.9744299], [40.6914524, -73.9678265], [40.8000117, -73.9701698], [40.7480655, -73.972862], [40.7756416, -73.9772063], [40.7400441, -73.9853702], [40.7235881, -73.9876419], [40.7707233, -73.9533504], [40.6339914, -73.9689071], [40.6925254, -73.9803939], [40.8539526, -73.9345678], [40.7280229, -74.0048053], [40.7740666, -73.9522989], [40.7324361, -73.9909751], [40.7314129, -73.9921518], [40.7733045, -73.9543976], [40.7249484, -74.0087079], [40.7737734, -73.9794676], [40.7500752, -73.9837835], [40.7917397, -73.9744247], [40.6666793, -73.9609528], [40.679581, -73.9812951], [40.7024285, -73.9888337], [40.7332472, -73.9543487], [40.6820161, -73.993894], [40.7205254, -74.0057286], [40.7776132, -73.9576916], [40.766423, -73.9640148], [40.7427598, -73.9940528], [40.7659512, -73.9884748], [40.7252187, -73.9929764], [40.7425001, -73.9908777], [40.7859464, -73.9741874], [40.7680768, -73.98663], [40.837124, -73.9478519], [40.7550328, -73.875632], [40.7576927, -73.9292082], [40.7313911, -74.0059008], [40.7493387, -73.9803235], [40.770517, -73.92144], [40.7144322, -73.9607567], [40.6726258, -73.9405975], [40.7484484, -73.9706936], [40.7346548, -73.982112], [40.6728165, -73.9850787], [40.8511379, -73.9399545], [40.7795712, -73.9540221], [40.7417859, -73.9558663], [40.7390659, -73.9937922], [40.7819416, -73.9506314], [40.7278259, -74.0021323], [40.7714227, -73.9542156], [40.7303011, -74.0043399], [40.871051, -73.916134], [40.7143903, -73.9911526], [40.7506343, -73.8477874], [40.7289147, -74.0046383], [40.6666793, -73.9609528], [40.7151591, -74.006685], [40.7892103, -73.9780213], [40.6950751, -73.9835386], [40.7372683, -73.9809854], [40.7372683, -73.9809854], [40.671435, -73.9389081], [40.6915526, -73.9932472], [40.7445839, -74.0023215], [40.7063162, -74.0169708], [40.7577737, -73.9667949], [40.747278, -73.8978449], [40.744024, -73.9784526], [40.6771471, -73.9634181], [40.7641461, -73.9901764], [40.7368391, -74.0073583], [40.8081041, -73.9210446], [40.747278, -73.8978449], [40.7354659, -73.9841568], [40.7662142, -73.9664942], [40.6848556, -73.9281863], [40.6848556, -73.9281863], [40.6848556, -73.9281863], [40.6848556, -73.9281863], [40.7538262, -73.9736465], [40.7270036, -74.0016423], [40.7761138, -73.9801195], [40.7343053, -73.9869055], [40.8163293, -73.9473251], [40.8225202, -73.8071197], [40.7388319, -73.9815337]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_c4adb35988f383587c97de89256ed9bf);
#                 return cluster;
#             })();
#
#
#             var layer_control_4458b50932f223bd69c32216b5d5dabf = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : t

# %%
folium_map.save('C:\Kaggle\Real Estate/mymap.html')
